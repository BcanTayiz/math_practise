# %% [markdown]
# # Theory
#
# We can make the motion as discrete type of systems and consider action speed as states.
# THen (x1,x2,x3),(x1,x2,x3) becomes group system. That motion system
#
# then for the motion, we can follow (x1,x2,x3),(x1,x2,x4),(x1,x2,x3),(x1,x2,x4) and so on and every motion could be cyclic
#
# if we define motions as subgroup actions, then we can determine the systems' motions as cyclic..

# %%
class Agent:

    def __init__(self):
